# %%
import pandas as pd
import numpy as np

data_all = pd.read_csv('../data/data_all.csv')

# %%
data_all.describe()
# Out:
#              index          Price      Rating   num_cores  num_threads  \
# count   991.000000     991.000000  991.000000  991.000000   991.000000
# mean    505.860747   77266.504541   63.931382    8.128153    12.191726
# std     287.899458   57384.910269   10.190575    4.215499     5.585115
# min       1.000000    9800.000000   24.000000    2.000000     0.000000
# 25%     258.500000   43595.000000   58.000000    6.000000     8.000000
# 50%     507.000000   61900.000000   64.000000    8.000000    12.000000
# 75%     754.500000   89245.000000   71.000000   10.000000    16.000000
# max    1002.000000  454490.000000   89.000000   24.000000    32.000000
#
#        ram_memory  primary_storage_capacity  secondary_storage_capacity  \
# count  991.000000                991.000000                  991.000000
# mean    13.047427                610.938446                    4.004036
# std      5.591188                266.927666                   33.553936
# ...

# %%
data_all.head(10)
# Out:
#    index    brand                                              Model  Price  \
# 0      1    tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2    tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3       hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3      4     acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5   lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# 5      6    apple  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...  70990
# 6      7  infinix  Infinix INBook Y2 Plus Laptop (11th Gen Core i...  34990
# 7      8     asus  Asus TUF Gaming F15 FX506HF-HN024W Gaming Lapt...  49990
# 8      9       hp  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  36990
# 9     10  infinix  Infinix Zerobook 2023 Laptop (13th Gen Core i9...  59990
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# ...

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       991 non-null    int64
#  1   brand                       991 non-null    object
#  2   Model                       991 non-null    object
#  3   Price                       991 non-null    int64
#  4   Rating                      991 non-null    int64
#  5   processor_brand             991 non-null    object
#  6   processor_tier              991 non-null    object
#  7   num_cores                   991 non-null    int64
#  8   num_threads                 991 non-null    int64
#  9   ram_memory                  991 non-null    int64
#  10  primary_storage_type        991 non-null    object
#  11  primary_storage_capacity    991 non-null    int64
#  12  secondary_storage_type      991 non-null    object
# ...

# %% [markdown]
# From this basic information we observe:
# <ul>
# <li> our dataset has 991 records, but for EDA and clustering we will use only 80% of it, other 20% goes to our validation team</li>
# <li> our dataset has 22 columns: 10 - int64, 1 - float64, 1 - bool, 10 - object (string)</li>
# <li> columns: index and Model do not contain any useful information (almost all info, written in Model already exists in other columns)</li>
# </ul>

# %%
# Any dublicates?
data_all.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h1> DIVISION INTO VALIDATION SET (FOR VALIDATION TEAM) AND OUR DATASET <h1>

# %%
from sklearn.model_selection import train_test_split

data, validation_data = train_test_split(data_all, test_size=0.2, random_state=42)

validation_data.to_csv('../data/validation_data.csv', index=False)
data.to_csv('../data/our_data.csv', index=False)

# %% [markdown]
# <h1>Exploration of columns</h1>

# %%
print(data.columns)
# Out:
# Index(['index', 'brand', 'Model', 'Price', 'Rating', 'processor_brand',
#        'processor_tier', 'num_cores', 'num_threads', 'ram_memory',
#        'primary_storage_type', 'primary_storage_capacity',
#        'secondary_storage_type', 'secondary_storage_capacity', 'gpu_brand',
#        'gpu_type', 'is_touch_screen', 'display_size', 'resolution_width',
#        'resolution_height', 'OS', 'year_of_warranty'],
#       dtype='object')

# %% [markdown]
# ### 'BRAND'

# %%
pd.unique(data['brand'])
# Out:
# array(['acer', 'lenovo', 'dell', 'asus', 'msi', 'hp', 'samsung', 'jio',
#        'apple', 'infinix', 'iball', 'lg', 'zebronics', 'tecno', 'fujitsu',
#        'microsoft', 'chuwi', 'avita', 'ultimus', 'honor', 'gigabyte',
#        'wings', 'realme', 'walker', 'primebook'], dtype=object)

# %% [markdown]
# column 'brand' has 25 different values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def get_barplot(column_name, data):
    counts = data[column_name].value_counts().sort_values()

    plt.figure(figsize=(10, 6))

    sns.barplot(x=counts.values, y=counts.index, color = '#4499F8')

    for index, value in enumerate(counts.values):
        plt.text(value, index, str(value), va='center')
        
    plt.title('Number of Observations per '+column_name)
    plt.xlabel('Count')
    plt.ylabel(column_name)

    plt.show()

get_barplot('brand', data)

# %% [markdown]
# ### 'PRICE'

# %%
sns.histplot(data=data, x="Price", kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ### 'RATING'

# %%
sns.histplot(data=data, x="Rating", kde=True)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Count'>

# %% [markdown]
# ### 'Processor brand'

# %%
pd.unique(data['processor_brand'])
# Out:
# array(['intel', 'amd', 'other', 'apple'], dtype=object)

# %% [markdown]
# processor_brand column has 4 different values

# %%
get_barplot('processor_brand', data)

# %% [markdown]
# ### 'processor tier'

# %%
pd.unique(data['processor_tier'])
# Out:
# array(['core i3', 'core i5', 'ryzen 5', 'core i7', 'ryzen 9', 'ryzen 7',
#        'other', 'm3', 'ryzen 3', 'core i9', 'celeron', 'm2', 'm1',
#        'core ultra 7', 'pentium'], dtype=object)

# %% [markdown]
# column processor tier has 15 different values

# %%
get_barplot('processor_tier', data)

# %% [markdown]
# ### 'NUM_CORES'

# %%
pd.unique(data['num_cores'])
# Out:
# array([ 6,  8, 14, 16, 12,  5,  2, 10,  4, 24, 11, 20])

# %%
sns.histplot(data=data, x="num_cores", kde=True)
# Out:
# <AxesSubplot: xlabel='num_cores', ylabel='Count'>

# %% [markdown]
# ### 'NUM_THREADS'

# %%
pd.unique(data['num_threads'])
# Out:
# array([ 8, 12, 20, 24, 16,  6,  4,  0, 32,  2, 22,  5, 11, 28, 14])

# %%
sns.histplot(data=data, x="num_threads", kde=True)
# Out:
# <AxesSubplot: xlabel='num_threads', ylabel='Count'>

# %% [markdown]
# ### 'RAM_MEMORY'

# %%
pd.unique(data['ram_memory'])
# Out:
# array([ 8, 16, 32,  4,  2, 12, 36])

# %%
sns.histplot(data=data, x="ram_memory", kde=True)
# Out:
# <AxesSubplot: xlabel='ram_memory', ylabel='Count'>

# %% [markdown]
# ### 'Primary_storage_type'

# %%
pd.unique(data['primary_storage_type'])
# Out:
# array(['SSD', 'HDD'], dtype=object)

# %% [markdown]
# primary_storage_type takes only 2 different values

# %%
get_barplot('primary_storage_type', data)

# %% [markdown]
# 'PRIMARY STORAGE CAPACITY'

# %%
pd.unique(data['primary_storage_capacity'])
# Out:
# array([ 512, 1024,   64,   32,  256, 2048,  128])

# %%
sns.histplot(data=data, x="primary_storage_capacity", kde=True)
# Out:
# <AxesSubplot: xlabel='primary_storage_capacity', ylabel='Count'>

# %% [markdown]
# ### 'OS'

# %%
pd.unique(data['OS'])
# Out:
# array(['windows', 'other', 'mac', 'dos', 'chrome', 'ubuntu'], dtype=object)

# %%
get_barplot('OS', data)

# %% [markdown]
# 'YEAR OF WARRANTY'

# %%
pd.unique(data['year_of_warranty'])
# Out:
# array(['1', '2', 'No information', '3'], dtype=object)

# %%
get_barplot('year_of_warranty', data)

# %% [markdown]
# ### 'RESOLUTION HEIGHT'

# %%
pd.unique(data['resolution_height'])
# Out:
# array([1080, 2160, 1200,  768, 1964, 1600, 2560, 1620, 1800, 1664, 1920,
#        2000, 1536, 1024, 1504, 1440,  800, 2234, 1660])

# %%
sns.histplot(data=data, x="resolution_height", kde=True)
# Out:
# <AxesSubplot: xlabel='resolution_height', ylabel='Count'>

# %% [markdown]
# ### 'RESOLUTION WIDTH'

# %%
pd.unique(data['resolution_width'])
# Out:
# array([1920, 3456, 1366, 3024, 2560, 1600, 2880, 1080, 3200, 3000, 2048,
#        1536, 2256, 3072, 1200, 1440, 1280])

# %%
sns.histplot(data=data, x="resolution_width", kde=True)
# Out:
# <AxesSubplot: xlabel='resolution_width', ylabel='Count'>

# %% [markdown]
# 'DISPLAY SIZE'

# %%
pd.unique(data['display_size'])
# Out:
# array([15.6, 14. , 16. , 13.3, 16.1, 11.6, 14.2, 17.3, 13.6, 18. , 13.5,
#        12.4, 14.5, 10.1, 14.1, 16.2, 13.4, 13. ])

# %%
sns.histplot(data=data, x="display_size", kde=True)
# Out:
# <AxesSubplot: xlabel='display_size', ylabel='Count'>

# %% [markdown]
# ### 'IS TOUCH SCREEN'

# %%
data['is_touch_screen'] = data['is_touch_screen'].astype(int)
data['is_touch_screen']

counts = data['is_touch_screen'].value_counts().sort_values()
plt.figure(figsize=(10, 6))
sns.barplot(x=counts.index, y=counts.values, color = '#4499F8')
plt.title('Number of Observations per is_touch_screen')
plt.xlabel('is_touch_screen')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 'SECONDARY STORAGE TYPE'

# %%
pd.unique(data['secondary_storage_type'])
# Out:
# array(['No secondary storage', 'SSD'], dtype=object)

# %% [markdown]
# Column secondary_storage_type contains only  2 different values

# %%
get_barplot('secondary_storage_type', data)

# %% [markdown]
# ### 'SECONDARY STORAGE CAPACITY'

# %%
pd.unique(data['secondary_storage_capacity'])
# Out:
# array([  0, 256, 128, 512])

# %%
sns.histplot(data=data, x="secondary_storage_capacity", kde=True)
# Out:
# <AxesSubplot: xlabel='secondary_storage_capacity', ylabel='Count'>

# %% [markdown]
# ### 'GPU_BRAND'

# %%
pd.unique(data['gpu_brand'])
# Out:
# array(['intel', 'amd', 'nvidia', 'arm', 'apple'], dtype=object)

# %%
get_barplot('gpu_brand', data)

# %%
data[data['gpu_brand'] == 'arm']
# Out:
#      index      brand                                              Model  \
# 192    203        jio  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...
# 952    964         hp  HP Chromebook x360 13b-ca0006MU Laptop (MediaT...
# 372    384  primebook  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...
#
#      Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# 192  14701      24           other          other          8            0
# 952  39551      43           other          other          8            0
# 372  12990      31           other          other          8            0
#
#      ram_memory  ... secondary_storage_type  secondary_storage_capacity  \
# 192           4  ...   No secondary storage                           0
# 952           8  ...   No secondary storage                           0
# 372           4  ...   No secondary storage                           0
#
#     gpu_brand    gpu_type is_touch_screen display_size  resolution_width  \
# ...

# %% [markdown]
# ### 'GPU TYPE'

# %%
pd.unique(data['gpu_type'])
# Out:
# array(['integrated', 'dedicated', 'apple'], dtype=object)

# %%
get_barplot('gpu_type', data)

# %% [markdown]
# ### 'total_number_of_pixels' - new column

# %%
data['total_number_of_pixels'] = data['resolution_height'] * data['resolution_width']

# %%
sns.histplot(data=data, x="total_number_of_pixels", kde=True)
# Out:
# <AxesSubplot: xlabel='total_number_of_pixels', ylabel='Count'>

# %% [markdown]
# ### 'total_pixels_per_square_of_diag' - new column

# %%
data['total_pixels_per_square_of_diag'] = data['total_number_of_pixels'] / (data['display_size'] ** 2)

# %%
sns.histplot(data=data, x="total_pixels_per_square_of_diag", kde=True)
# Out:
# <AxesSubplot: xlabel='total_pixels_per_square_of_diag', ylabel='Count'>

# %% [markdown]
# ### Is there something that can be extracted from Model ?

# %%
# display all information from Model
pd.set_option('display.max_columns', None)
pd.unique(data['Model'])
# Out:
# array(['Acer Aspire 3 A315-59 NX.K6TSI.00C Laptop (12th Gen Core i3/ 8GB/ 512GB SSD/ Win11)',
#        'Lenovo IdeaPad Slim 3 83ER008DIN Laptop (12th Gen Core i5/ 16GB/ 512GB SSD/ Win11)',
#        'Dell Vostro 3425 Laptop (AMD Ryzen 5 5625U/ 8GB/ 512GB SSD/ Win11 Home)',
#        'Dell XPS 9530 2023 Laptop (13th Gen Core i7/ 32GB/ 1TB SSD/ Win11/ 6GB Graph)',
#        'Acer Predator Helios Neo 16 PHN16-71 Gaming Laptop (13th Gen Core i7/ 16GB/ 1TB SSD/ Win11/ 6GB Graph)',
#        'Asus TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop (AMD Ryzen 9 7940HS/ 16GB/ 1TB SSD/ Win11 Home/ 6GB Graph)',
#        'MSI Prestige 13 Evo A13M-063IN Laptop(13th Gen Core i7/ 16 GB/ 1TB SSD/Win11 Home)',
#        'Asus Vivobook 15X OLED 2023 K3504VA-LK552WS Laptop (13th Gen Core i5/ 16GB/ 1TB SSD/ Win11 Home)',
#        'Dell Inspiron 3530 2023 Laptop (13th Gen Core i3/ 8GB/ 1TB SSD/ Win11 Home)',
#        'HP Omen 16-xd0005AX Gaming Laptop (AMD Ryzen 7 7840HS/ 16GB/ 1TB SSD/ Win11/ 6GB Graph)',
# ...

# %%
currency_rate = 0.012  # conversion rate from Indian rupees to USD

# %%
# Currency change
df = pd.DataFrame(data)
df['Price'] = df['Price'] * currency_rate
df['Price'] = df['Price'].round(2)

# %%
data
# Out:
#      index   brand                                              Model  \
# 215    226    acer  Acer Aspire 3 A315-59 NX.K6TSI.00C Laptop (12t...
# 294    306  lenovo  Lenovo IdeaPad Slim 3 83ER008DIN Laptop (12th ...
# 49      53    dell  Dell Vostro 3425 Laptop (AMD Ryzen 5 5625U/ 8G...
# 720    732    dell  Dell XPS 9530 2023 Laptop (13th Gen Core i7/ 3...
# 235    246    acer  Acer Predator Helios Neo 16 PHN16-71 Gaming La...
# ..     ...     ...                                                ...
# 106    114    acer  Acer Aspire Lite AL15 Laptop (AMD Ryzen 5 5500...
# 270    281      hp  HP Victus 15-fb0050AX Gaming Laptop (AMD Ryzen...
# 860    872    dell  Dell Vostro 15 3510 2023 Laptop (11th Gen Core...
# 435    447      hp  HP 240 G9 821J4PA Laptop (12th Gen Core i5/ 8G...
# 102    109      hp  HP Victus15-fb0147AX Gaming Laptop (Ryzen 5 56...
#
#        Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %% [markdown]
# ## Boxplots

# %%
data.describe()
# Out:
#              index        Price      Rating   num_cores  num_threads  \
# count   792.000000   792.000000  792.000000  792.000000   792.000000
# mean    501.988636   921.564899   63.890152    8.099747    12.151515
# std     288.840856   691.234902    9.994907    4.097596     5.437127
# min       1.000000   117.600000   24.000000    2.000000     0.000000
# 25%     250.750000   523.710000   58.000000    6.000000     8.000000
# 50%     500.500000   741.670000   64.000000    8.000000    12.000000
# 75%     749.250000  1055.880000   71.000000   10.000000    16.000000
# max    1002.000000  5453.880000   89.000000   24.000000    32.000000
#
#        ram_memory  primary_storage_capacity  secondary_storage_capacity  \
# count  792.000000                792.000000                  792.000000
# mean    12.896465                608.242424                    3.717172
# std      5.364055                264.882450                   32.923477
# ...

# %%
data.isnull().sum()
# Out:
# index                              0
# brand                              0
# Model                              0
# Price                              0
# Rating                             0
# processor_brand                    0
# processor_tier                     0
# num_cores                          0
# num_threads                        0
# ram_memory                         0
# primary_storage_type               0
# primary_storage_capacity           0
# secondary_storage_type             0
# secondary_storage_capacity         0
# gpu_brand                          0
# gpu_type                           0
# is_touch_screen                    0
# display_size                       0
# resolution_width                   0
# resolution_height                  0
# OS                                 0
# year_of_warranty                   0
# total_number_of_pixels             0
# total_pixels_per_square_of_diag    0
# dtype: int64

# %%
import math

# %% [markdown]
# #### What to do with outliers

# %%
for column in ['Price', 'Rating', 'num_cores', 'num_threads', 'ram_memory', 'primary_storage_capacity', 'secondary_storage_capacity', 'display_size', 'resolution_width', 'resolution_height']:
    plt.title(column)
    sns.boxplot(data[column], color='lightblue')
    plt.show()

# %% [markdown]
# There are some outliers, but we have checked the prices of the most expensive laptops, and we see that these prices are real, so we decided to leave this outliers, because they are real data.

# %%
df = pd.DataFrame(data)

brand_counts = df['brand'].value_counts()
brand_top_values = np.array(brand_counts[brand_counts >= 5].index.tolist())
processor_brand_values = pd.unique(data['processor_brand'])
primary_storage_type_values = pd.unique(data['primary_storage_type'])
gpu_brand_values = pd.unique(data['gpu_brand'])
OS_counts = df['OS'].value_counts()
OS_top_values = np.array(OS_counts[OS_counts > 2].index.tolist())

# %%
y_min = data['Price'].min() - 100
y_max = data['Price'].max() + 100

# %%
plt.figure(figsize=(40, 10))
i = 1
for val in brand_top_values:
    filtered_df = df[df['brand'] == val]
    plot = plt.subplot(1, 11, i)
    sns.boxplot(y=filtered_df['Price'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min, y_max)
    i += 1

plt.suptitle('Boxplots of Price for the most popular Brands', fontsize=40)
plt.show()

# %%
y_min_rating = data['Rating'].min() - 5
y_max_rating = data['Rating'].max() + 5

# %%
plt.figure(figsize=(40, 10))
i = 1
for val in brand_top_values:
    filtered_df = df[df['brand'] == val]
    plot = plt.subplot(1, 11, i)
    sns.boxplot(y=filtered_df['Rating'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min_rating, y_max_rating)
    i += 1

plt.suptitle('Boxplots of Rating for the most popular Brands', fontsize=40)
plt.show()

# %%
plt.figure(figsize=(40, 15))
i = 1
for val in processor_brand_values:
    filtered_df = df[df['processor_brand'] == val]
    plot = plt.subplot(1, 4, i)
    sns.boxplot(y=filtered_df['Price'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min, y_max)
    i += 1

plt.suptitle('Boxplots of Price for different Processor brands', fontsize=40)
plt.show()

# %%
plt.figure(figsize=(40, 15))
i = 1
for val in processor_brand_values:
    filtered_df = df[df['processor_brand'] == val]
    plot = plt.subplot(1, 4, i)
    sns.boxplot(y=filtered_df['Rating'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min_rating, y_max_rating)
    i += 1

plt.suptitle('Boxplots of Rating for different Processor brands', fontsize=40)
plt.show()

# %%
plt.figure(figsize=(30, 10))
i = 1
for val in primary_storage_type_values:
    filtered_df = df[df['primary_storage_type'] == val]
    plot = plt.subplot(1, 2, i)
    sns.boxplot(y=filtered_df['Price'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min, y_max)
    i += 1

plt.suptitle('Boxplots of Price for different Primary storage types', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(40, 15))
i = 1
for val in gpu_brand_values:
    filtered_df = df[df['gpu_brand'] == val]
    plot = plt.subplot(1, 5, i)
    sns.boxplot(y=filtered_df['Price'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min, y_max)
    i += 1

plt.suptitle('Boxplots of Price for different GPU brands', fontsize=40)
plt.show()

# %%
plt.figure(figsize=(40, 15))
i = 1
for val in gpu_brand_values:
    filtered_df = df[df['gpu_brand'] == val]
    plot = plt.subplot(1, 5, i)
    sns.boxplot(y=filtered_df['Rating'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min_rating, y_max_rating)
    i += 1

plt.suptitle('Boxplots of Rating for different GPU brands', fontsize=40)
plt.show()

# %%
plt.figure(figsize=(40, 15))
i = 1
for val in OS_top_values:
    filtered_df = df[df['OS'] == val]
    plot = plt.subplot(1, 4, i)
    sns.boxplot(y=filtered_df['Price'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min, y_max)
    i += 1

plt.suptitle('Boxplots of Price for the most popular Operating systems', fontsize=40)
plt.show()

# %%
plt.figure(figsize=(40, 15))
i = 1
for val in OS_top_values:
    filtered_df = df[df['OS'] == val]
    plot = plt.subplot(1, 4, i)
    sns.boxplot(y=filtered_df['Rating'], color='lightblue')
    plot.set_xlabel(val, weight='bold', size=20)
    plt.ylim(y_min_rating, y_max_rating)
    i += 1

plt.suptitle('Boxplots of Rating for the most popular Operating systems', fontsize=40)
plt.show()

# %% [markdown]
# #### Saving data for Preprocessing notebook

# %%
data.to_csv('../data/our_data.csv', index=False)
