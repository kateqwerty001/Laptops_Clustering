# %%
import pandas as pd
import numpy as np

data = pd.read_csv('../data/our_data.csv')
prep_data = pd.read_csv('../data/our_data_preprocessed_MinMaxScaler.csv')

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=30)
pca.fit(prep_data)

plt.plot(np.cumsum(pca.explained_variance_ratio_))

print(pca.explained_variance_ratio_)
# Out:
# [0.39443188 0.14799188 0.10995117 0.05450455 0.05410018 0.03585665
#  0.03205749 0.02687827 0.02332687 0.02111295 0.0175661  0.01523378
#  0.0126068  0.00803951 0.0052309  0.00488252 0.00459151 0.00342125
#  0.00327708 0.00286596 0.00285091 0.00214224 0.00198638 0.00164731
#  0.00143848 0.00123342 0.00118765 0.00110006 0.00093778 0.00079682]
